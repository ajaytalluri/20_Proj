# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df_train=pd.read_excel("C:\\Pandasdata\\DT_files\\rest_train.xlsx")

# %%
df_test=pd.read_excel("C:\\Pandasdata\\DT_files\\rest_test.xlsx")

# %%
df_train.head()
# Out:
#                TITLE  RESTAURANT_ID  \
# 0      CASUAL DINING           9438
# 1  CASUAL DINING,BAR          13198
# 2      CASUAL DINING          10915
# 3        QUICK BITES           6346
# 4     DESSERT PARLOR          15387
#
#                                      CUISINES  \
# 0                 Malwani, Goan, North Indian
# 1              Asian, Modern Indian, Japanese
# 2  North Indian, Chinese, Biryani, Hyderabadi
# 3                            Tibetan, Chinese
# 4                                    Desserts
#
#                                      TIME     CITY        LOCALITY RATING  \
# 0  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)    Thane  Dombivali East    3.6
# 1                    6pm – 11pm (Mon-Sun)  Chennai       Ramapuram    4.2
# 2     11am – 3:30pm, 7pm – 11pm (Mon-Sun)  Chennai      Saligramam    3.8
# 3                 11:30am – 1am (Mon-Sun)   Mumbai     Bandra West    4.1
# 4                    11am – 1am (Mon-Sun)   Mumbai     Lower Parel    3.8
#
# ...

# %%
df_test.head()
# Out:
#            TITLE  RESTAURANT_ID                                      CUISINES  \
# 0  CASUAL DINING           4085         North Indian, Chinese, Mughlai, Kebab
# 1    QUICK BITES          12680  South Indian, Fast Food, Pizza, North Indian
# 2  CASUAL DINING           1411       North Indian, Seafood, Biryani, Chinese
# 3           None            204                                       Biryani
# 4    QUICK BITES          13453                          South Indian, Kerala
#
#                                                 TIME       CITY      LOCALITY  \
# 0                      12noon – 12midnight (Mon-Sun)      Noida     Sector 18
# 1                            7am – 12:30AM (Mon-Sun)     Mumbai    Grant Road
# 2                           11am – 11:30pm (Mon-Sun)     Mumbai  Marine Lines
# 3  9am – 10pm (Mon, Wed, Thu, Fri, Sat, Sun), 10:...  Faridabad           NIT
# 4                              11am – 10pm (Mon-Sun)      Kochi        Kaloor
#
#   RATING       VOTES
# ...

# %%
df_train["source"]="train"
df_test['source']='test'

# %%
df=pd.concat([df_train,df_test])

# %%
df.head()
# Out:
#                TITLE  RESTAURANT_ID  \
# 0      CASUAL DINING           9438
# 1  CASUAL DINING,BAR          13198
# 2      CASUAL DINING          10915
# 3        QUICK BITES           6346
# 4     DESSERT PARLOR          15387
#
#                                      CUISINES  \
# 0                 Malwani, Goan, North Indian
# 1              Asian, Modern Indian, Japanese
# 2  North Indian, Chinese, Biryani, Hyderabadi
# 3                            Tibetan, Chinese
# 4                                    Desserts
#
#                                      TIME     CITY        LOCALITY RATING  \
# 0  11am – 4pm, 7:30pm – 11:30pm (Mon-Sun)    Thane  Dombivali East    3.6
# 1                    6pm – 11pm (Mon-Sun)  Chennai       Ramapuram    4.2
# 2     11am – 3:30pm, 7pm – 11pm (Mon-Sun)  Chennai      Saligramam    3.8
# 3                 11:30am – 1am (Mon-Sun)   Mumbai     Bandra West    4.1
# 4                    11am – 1am (Mon-Sun)   Mumbai     Lower Parel    3.8
#
# ...

# %%
df.shape
# Out:
# (16921, 10)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.dtypes
# Out:
# TITLE             object
# RESTAURANT_ID      int64
# CUISINES          object
# TIME              object
# CITY              object
# LOCALITY          object
# RATING            object
# VOTES             object
# COST             float64
# source            object
# dtype: object

# %%
for cols in df.columns:
    if df[cols].dtype=='object':
        print(df[cols].value_counts())
        print()
# Out:
# QUICK BITES                 5634
# CASUAL DINING               4910
# None                        1287
# CAFÉ                         830
# DESSERT PARLOR               508
#                             ...
# QUICK BITES,MEAT SHOP          1
# MEAT SHOP                      1
# DESSERT PARLOR,KIOSK           1
# MICROBREWERY,LOUNGE            1
# BEVERAGE SHOP,FOOD COURT       1
# Name: TITLE, Length: 123, dtype: int64
#
# North Indian                                            716
# North Indian, Chinese                                   714
# South Indian                                            706
# Fast Food                                               364
# Chinese                                                 226
#                                                        ...
# North Indian, Chinese, European, Finger Food              1
# North Indian, Asian, Continental, Italian                 1
# Chinese, Lebanese, Arabian                                1
# ...

# %%
for cols in df.columns:
    if df[cols].dtype=='object':
        print(df[cols].nunique())
        print()
# Out:
# 123
#
# 5183
#
# 3295
#
# 450
#
# 1636
#
# 32
#
# 2075
#
# 2

# %%
#checking Null values
df.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY              147
# LOCALITY          128
# RATING              4
# VOTES            1606
# COST             4231
# source              0
# dtype: int64

# %%
df['VOTES']
# Out:
# 0         49 votes
# 1         30 votes
# 2        221 votes
# 3         24 votes
# 4        165 votes
#            ...
# 16916    287 votes
# 16917    469 votes
# 16918     53 votes
# 16919          NaN
# 16920     63 votes
# Name: VOTES, Length: 16921, dtype: object

# %%
# Replacing 1606 nan values in Votes to 0
df['VOTES'].fillna(0,inplace=True)

# %%
# we can also strip text "votes" and make it int
df['VOTES'].loc[df['VOTES'].str[-5:]=='votes']=df['VOTES'].loc[df['VOTES'].str[-5:]=='votes'].str.rstrip("votes")

# %%
df['VOTES']
# Out:
# 0         49
# 1         30
# 2        221
# 3         24
# 4        165
#          ...
# 16916    287
# 16917    469
# 16918     53
# 16919       0
# 16920     63
# Name: VOTES, Length: 16921, dtype: object

# %%
df['VOTES']=df['VOTES'].astype(int)

# %%
df.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY              147
# LOCALITY          128
# RATING              4
# VOTES               0
# COST             4231
# source              0
# dtype: int64

# %%
df['RATING'].value_counts()
# Out:
# 3.9    1643
# 3.8    1604
# 4.0    1498
# 3.7    1437
# 3.6    1261
# 4.1    1217
# 3.5     988
# 4.2     968
# NEW     930
# 3.4     777
# 4.3     740
# -       672
# 3.3     485
# 4.4     484
# 3.2     349
# 4.5     274
# 3.1     263
# 2.9     242
# 3.0     229
# 2.8     191
# 4.6     184
# 2.7     129
# 4.7      90
# 2.6      85
# 2.5      51
# 4.8      49
# 4.9      28
# 2.4      24
# 2.3      15
# 2.1       4
# 2.2       4
# 2.0       2
# Name: RATING, dtype: int64

# %%
# there are NEW and '-' in the Rating. let us replace them
df["RATING"].replace("NEW",0,inplace=True)
df["RATING"].replace("-",0,inplace=True)
df["RATING"].fillna(0,inplace=True)

# %%
df['RATING'].isnull().sum()
# Out:
# 0

# %%
df['RATING']=df['RATING'].astype(float)

# %%
df.dtypes
# Out:
# TITLE             object
# RESTAURANT_ID      int64
# CUISINES          object
# TIME              object
# CITY              object
# LOCALITY          object
# RATING           float64
# VOTES              int32
# COST             float64
# source            object
# dtype: object

# %%
df.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY              147
# LOCALITY          128
# RATING              0
# VOTES               0
# COST             4231
# source              0
# dtype: int64

# %%
df["CITY"].fillna("missing",inplace=True)
df["LOCALITY"].fillna("missing",inplace=True)

# %%
df.isnull().sum()
# Out:
# TITLE               0
# RESTAURANT_ID       0
# CUISINES            0
# TIME                0
# CITY                0
# LOCALITY            0
# RATING              0
# VOTES               0
# COST             4231
# source              0
# dtype: int64

# %%
df
# Out:
#                    TITLE  RESTAURANT_ID  \
# 0          CASUAL DINING           9438
# 1      CASUAL DINING,BAR          13198
# 2          CASUAL DINING          10915
# 3            QUICK BITES           6346
# 4         DESSERT PARLOR          15387
# ...                  ...            ...
# 16916      CASUAL DINING           9057
# 16917               None           1247
# 16918        QUICK BITES           8617
# 16919        QUICK BITES           6485
# 16920        QUICK BITES           2421
#
#                                             CUISINES  \
# 0                        Malwani, Goan, North Indian
# 1                     Asian, Modern Indian, Japanese
# 2         North Indian, Chinese, Biryani, Hyderabadi
# 3                                   Tibetan, Chinese
# 4                                           Desserts
# ...                                              ...
# 16916                 North Indian, Mughlai, Chinese
# ...

# %%
# let us strip Title and cusines in to multiple columns.
# before that let us remove Restaurant ID and Time
df.drop('RESTAURANT_ID',axis=1,inplace=True)
df.drop('TIME',axis=1,inplace=True)

# %%
# we will see how many splits were there in Cusine
max_cusine=1
for i in range(len(df['CUISINES'])):
    temp =len(df['CUISINES'].iloc[i].split(","))
    if temp > max_cusine:
        max_cusine=temp
print("Max Cusines= ",max_cusine)
# Out:
# Max Cusines=  8

# %%
c1=list()
c2=list()
c3=list()
c4=list()
c5=list()
c6=list()
c7=list()
c8=list()

for i in range(len(df['CUISINES'])):
    temp=df["CUISINES"].iloc[i].split(",")
    
    try:
        c1.append(temp[0].strip().upper())
    except :
        c1.append('NONE')
    try :
        c2.append(temp[1].strip().upper())
    except :
        c2.append('NONE')
    try :
        c3.append(temp[2].strip().upper())
    except :
        c3.append('NONE')
    try :
        c4.append(temp[3].strip().upper())
    except :
        c4.append('NONE')
    try :
        c5.append(temp[4].strip().upper())
    except :
        c5.append('NONE')
    try :
        c6.append(temp[5].strip().upper())
    except :
        c6.append('NONE')
    try :
        c7.append(temp[6].strip().upper())
    except :
        c7.append('NONE')
    try :
        c8.append(temp[7].strip().upper())
    except :
        c8.append('NONE')

# %%
df["c1"]=c1
df["c2"]=c2
df["c3"]=c3
df["c4"]=c4
df["c5"]=c5
df["c6"]=c6
df["c7"]=c7
df["c8"]=c8

# %%
# in the same way let us also split Title
max_title=1
for i in range(len(df['TITLE'])):
    temp =len(df["TITLE"].iloc[i].split(","))
    if temp > max_title:
        max_title=temp
print("Max No of Titles are= ", max_title)
# Out:
# Max No of Titles are=  2

# %%
t1=list()
t2=list()

# %%
for i in range(len(df["TITLE"])):
    temp=df["TITLE"].iloc[i].split(",")
    try :
        t1.append(temp[0].strip().upper())
    except :
        t1.append('NONE')
    try :
        t2.append(temp[1].strip().upper())
    except :
        t2.append('NONE')

# %%
df['t1']=t1
df['t2']=t2

# %%
df
# Out:
#                    TITLE                                       CUISINES  \
# 0          CASUAL DINING                    Malwani, Goan, North Indian
# 1      CASUAL DINING,BAR                 Asian, Modern Indian, Japanese
# 2          CASUAL DINING     North Indian, Chinese, Biryani, Hyderabadi
# 3            QUICK BITES                               Tibetan, Chinese
# 4         DESSERT PARLOR                                       Desserts
# ...                  ...                                            ...
# 16916      CASUAL DINING                 North Indian, Mughlai, Chinese
# 16917               None  Biryani, North Indian, Sandwich, Salad, Wraps
# 16918        QUICK BITES                      Continental, North Indian
# 16919        QUICK BITES                               Rolls, Beverages
# 16920        QUICK BITES                                        Mughlai
#
#               CITY          LOCALITY  RATING  VOTES    COST source  \
# ...

# %%
df.drop(columns=["CUISINES","TITLE"],inplace=True)

# %%
df.dtypes
# Out:
# CITY         object
# LOCALITY     object
# RATING      float64
# VOTES         int32
# COST        float64
# source       object
# c1           object
# c2           object
# c3           object
# c4           object
# c5           object
# c6           object
# c7           object
# c8           object
# t1           object
# t2           object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
for col in df.columns:
    if df[col].dtype=="object":
        df[col]=LabelEncoder().fit_transform(df[col])

# %%
df
# Out:
#        CITY  LOCALITY  RATING  VOTES    COST  source   c1  c2  c3  c4  c5  c6  \
# 0       400       328     3.6     49  1200.0       1   61  32  72  64  62  50
# 1        75      1214     4.2     30  1500.0       1    6  62  45  64  62  50
# 2        75      1272     3.8    221   800.0       1   74  23  14  34  62  50
# 3       277       161     4.1     24   800.0       1  102  23  70  64  62  50
# 4       277       709     3.8    165   300.0       1   30  67  70  64  62  50
# ...     ...       ...     ...    ...     ...     ...  ...  ..  ..  ..  ..  ..
# 16916   316      1184     3.9    287     NaN       0   74  64  23  64  62  50
# 16917    42       461     4.3    469     NaN       0   15  69  83  73  83  50
# 16918   128      1370     3.7     53     NaN       0   29  69  70  64  62  50
# 16919   216       642     0.0      0     NaN       0   84  12  70  64  62  50
# 16920    40      1148     3.7     63     NaN       0   69  67  70  64  62  50
#
#        c7  c8  t1  t2
# ...

# %%
df.dtypes
# Out:
# CITY          int32
# LOCALITY      int32
# RATING      float64
# VOTES         int32
# COST        float64
# source        int32
# c1            int32
# c2            int32
# c3            int32
# c4            int32
# c5            int32
# c6            int32
# c7            int32
# c8            int32
# t1            int32
# t2            int32
# dtype: object

# %%
# Splitting the dataset
df_train=df.loc[df["source"]==1]
df_test=df.loc[df["source"]==0]

# %%
df_test.reset_index(drop=True,inplace=True)

# %%
df_train.drop(columns=["source"],inplace=True)
df_test.drop(columns=["source"],inplace=True)

# %%
x=df_train.drop(columns=["COST"])
y=df_train[["COST"]]

# %%
x.shape,y.shape
# Out:
# ((12690, 14), (12690, 1))

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, r2_score
def max_r2_score(algo,x,y):
    max_r_score=0
    for r_state in range(42,100):
        x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.20)
        algo.fit(x_train,y_train)
        y_pred = algo.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print("r2 score corresponding to ",r_state," is ",r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print("max r2 score corresponding to ",final_r_state," is ",max_r_score)
    return final_r_state

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
max_r2_score(lr,x,y)
# Out:
# r2 score corresponding to  42  is  0.20991089335055102
# r2 score corresponding to  43  is  0.1821078975374434
# r2 score corresponding to  44  is  0.1894847621225233
# r2 score corresponding to  45  is  0.2049669320443106
# r2 score corresponding to  46  is  0.21703373736882658
# r2 score corresponding to  47  is  0.18573537813603513
# r2 score corresponding to  48  is  0.15152286658184977
# r2 score corresponding to  49  is  0.14433241184485512
# r2 score corresponding to  50  is  0.16732458661656735
# r2 score corresponding to  51  is  0.22354379924455559
# r2 score corresponding to  52  is  0.13157227829201168
# r2 score corresponding to  53  is  0.22194668808588625
# r2 score corresponding to  54  is  0.1612088447014317
# r2 score corresponding to  55  is  0.21204197727958385
# r2 score corresponding to  56  is  0.19849926584081523
# r2 score corresponding to  57  is  0.20722098869274796
# r2 score corresponding to  58  is  0.1569394166011796
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
dtr=DecisionTreeRegressor()
max_r2_score(dtr,x,y)
# Out:
# r2 score corresponding to  42  is  0.47411405338634494
# r2 score corresponding to  43  is  0.49602467677654316
# r2 score corresponding to  44  is  0.408404729368534
# r2 score corresponding to  45  is  0.48786606253747755
# r2 score corresponding to  46  is  0.42706264898573043
# r2 score corresponding to  47  is  0.5322416465455877
# r2 score corresponding to  48  is  -0.01558493071963496
# r2 score corresponding to  49  is  0.45011113915764267
# r2 score corresponding to  50  is  0.09026635352573897
# r2 score corresponding to  51  is  0.468458779620724
# r2 score corresponding to  52  is  0.39698052512977544
# r2 score corresponding to  53  is  0.4933364860010392
# r2 score corresponding to  54  is  0.37746964198436117
# r2 score corresponding to  55  is  0.4620579086062975
# r2 score corresponding to  56  is  0.5042644898556001
# r2 score corresponding to  57  is  0.4234440507369833
# r2 score corresponding to  58  is  0.4699078974152773
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
rf =RandomForestRegressor()
parameters={"n_estimators":[10,100,500]}
gsv=GridSearchCV(rf,parameters,cv=5,scoring='r2')
gsv.fit(x,y)
gsv.best_params_
# Out:
# {'n_estimators': 500}

# %%
rf=RandomForestRegressor(n_estimators=500)
max_r2_score(rf,x,y)
# Out:
# r2 score corresponding to  42  is  0.734899857781832
# r2 score corresponding to  43  is  0.7465675226214585
# r2 score corresponding to  44  is  0.7170544903952429
# r2 score corresponding to  45  is  0.6970113962493943
# r2 score corresponding to  46  is  0.7380638252891718
# r2 score corresponding to  47  is  0.7101764166345046
# r2 score corresponding to  48  is  0.6053212207780161
# r2 score corresponding to  49  is  0.6398120468838919
# r2 score corresponding to  50  is  0.7107518799496103
# r2 score corresponding to  51  is  0.725585835588533
# r2 score corresponding to  52  is  0.6211317597471926
# r2 score corresponding to  53  is  0.7243635677229397
# r2 score corresponding to  54  is  0.6930073326834528
# r2 score corresponding to  55  is  0.752072681502419
# r2 score corresponding to  56  is  0.7248664742415902
# r2 score corresponding to  57  is  0.6866018831072848
# r2 score corresponding to  58  is  0.6308617156116023
# ...

# %%
from sklearn.svm import SVR
svr=SVR()
parameters={"kernel":["linear", "poly", "rbf"]}
gsv = GridSearchCV(svr, parameters, cv=5,scoring="r2")
gsv.fit(x,y)
gsv.best_params_
# Out:
# {'kernel': 'linear'}

# %%
svr=SVR(kernel='linear')
max_r2_score(svr,x,y)
# Out:
# r2 score corresponding to  42  is  0.16290972887392474
# r2 score corresponding to  43  is  0.12831760856187657
# r2 score corresponding to  44  is  0.1489104153026074
# r2 score corresponding to  45  is  0.15864599491246711
# r2 score corresponding to  46  is  0.17123206083141906
# r2 score corresponding to  47  is  0.13081188930261156
# r2 score corresponding to  48  is  0.09474412849633362
# r2 score corresponding to  49  is  0.10291131141841425
# r2 score corresponding to  50  is  0.10595102669713552
# r2 score corresponding to  51  is  0.1838664297705096
# r2 score corresponding to  52  is  0.09241335072848422
# r2 score corresponding to  53  is  0.18885564473202188
# r2 score corresponding to  54  is  0.11605651033304476
# r2 score corresponding to  55  is  0.17056998614164498
# r2 score corresponding to  56  is  0.15633102812095268
# r2 score corresponding to  57  is  0.16820296667449142
# r2 score corresponding to  58  is  0.10499085373228612
# ...

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()
max_r2_score(gbr,x,y)
# Out:
# r2 score corresponding to  42  is  0.71215207857654
# r2 score corresponding to  43  is  0.72784917572558
# r2 score corresponding to  44  is  0.7194807300325492
# r2 score corresponding to  45  is  0.6758265527591675
# r2 score corresponding to  46  is  0.7162502147850575
# r2 score corresponding to  47  is  0.6934362577838136
# r2 score corresponding to  48  is  0.6987095903968223
# r2 score corresponding to  49  is  0.6109747917794406
# r2 score corresponding to  50  is  0.7164391509479868
# r2 score corresponding to  51  is  0.7107150019785573
# r2 score corresponding to  52  is  0.607971174647485
# r2 score corresponding to  53  is  0.6936946322418419
# r2 score corresponding to  54  is  0.7077463308304748
# r2 score corresponding to  55  is  0.7076609154075273
# r2 score corresponding to  56  is  0.6688112777054936
# r2 score corresponding to  57  is  0.6924940585898385
# r2 score corresponding to  58  is  0.6121426313380323
# ...

# %%
rf=RandomForestRegressor(n_estimators=500)
x_train, x_test,y_train, y_test =train_test_split(x,y,random_state=55, test_size=0.2)
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)

print("Mean Sq Error =", mean_squared_error(y_test,y_pred))
print("R2 Score= ", r2_score(y_test,y_pred))
print()
rmsle_scr=np.sqrt(mean_squared_log_error(y_test,y_pred))
print("RMSLE =", rmsle_scr)
# Out:
# Mean Sq Error = 89134.02214940767
# R2 Score=  0.7508603064593814
#
# RMSLE = 0.3892574025894957

# %%
import lightgbm as lgb

# %%
lg = lgb.LGBMRegressor(silent=False)
max_r2_score(lg,x,y)
# Out:
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.002584 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1056
# [LightGBM] [Info] Number of data points in the train set: 10152, number of used features: 14
# [LightGBM] [Info] Start training from score 659.003940
# r2 score corresponding to  42  is  0.7489461633035385
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001013 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1055
# [LightGBM] [Info] Number of data points in the train set: 10152, number of used features: 14
# [LightGBM] [Info] Start training from score 656.597813
# r2 score corresponding to  43  is  0.7646019400624386
# ...

# %%
lg = lgb.LGBMRegressor(silent=False)
x_train, x_test,y_train, y_test =train_test_split(x,y,random_state=43, test_size=0.2)
lg.fit(x_train,y_train)
y_pred=lg.predict(x_test)
print("Mean Sq Error =", mean_squared_error(y_test,y_pred))
print("R2 Score= ", r2_score(y_test,y_pred))
print()
rmsle_scr=np.sqrt(mean_squared_log_error(y_test,y_pred))
print("RMSLE =", rmsle_scr)
# Out:
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001365 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1055
# [LightGBM] [Info] Number of data points in the train set: 10152, number of used features: 14
# [LightGBM] [Info] Start training from score 656.597813
# Mean Sq Error = 92991.47681409265
# R2 Score=  0.7646019400624386
#
# RMSLE = 0.4011537519355022

# %%
# we will finalize lgb model as the R2 score is high

# %%
df_test.drop('COST',axis=1,inplace=True)

# %%
rest_cost_pred_lg=lg.predict(df_test)

# %%
rest_cost_pred_lg
# Out:
# array([612.10625384, 612.10625384, 612.10625384, ..., 612.10625384,
#        520.08452192, 612.10625384])

# %%
rest_cost_pred_lg=pd.DataFrame(rest_cost_pred_lg,columns=["COST"])

# %%
rest_cost_pred_lg.to_csv("Restaurat_cost_Predictions.csv",index=False)

# %%
import joblib
joblib.dump(lg,'Restaurant_cost_lg.pkl')
# Out:
# ['Restaurant_cost_lg.pkl']
