# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:\\Pandasdata\\DT_files\\adult.csv",header =None)

# %%
df.head()
# Out:
#    0                  1       2           3   4                    5   \
# 0  39          State-gov   77516   Bachelors  13        Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13   Married-civ-spouse
# 2  38            Private  215646     HS-grad   9             Divorced
# 3  53            Private  234721        11th   7   Married-civ-spouse
# 4  28            Private  338409   Bachelors  13   Married-civ-spouse
#
#                    6               7       8        9     10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male  2174   0  40
# 1     Exec-managerial         Husband   White     Male     0   0  13
# 2   Handlers-cleaners   Not-in-family   White     Male     0   0  40
# 3   Handlers-cleaners         Husband   Black     Male     0   0  40
# 4      Prof-specialty            Wife   Black   Female     0   0  40
#
#                13      14
# 0   United-States   <=50K
# 1   United-States   <=50K
# 2   United-States   <=50K
# ...

# %% [raw]
# Attribute Information:
#
# age: continuous.
# workclass: Private, Self-emp-not-inc, Self-emp-inc, Federal-gov, Local-gov, State-gov, Without-pay, Never-worked.
# fnlwgt: continuous.
# education: Bachelors, Some-college, 11th, HS-grad, Prof-school, Assoc-acdm, Assoc-voc, 9th, 7th-8th, 12th, Masters, 1st-4th, 10th, Doctorate, 5th-6th, Preschool.
# education-num: continuous.
# marital-status: Married-civ-spouse, Divorced, Never-married, Separated, Widowed, Married-spouse-absent, Married-AF-spouse.
# occupation: Tech-support, Craft-repair, Other-service, Sales, Exec-managerial, Prof-specialty, Handlers-cleaners, Machine-op-inspct, Adm-clerical, Farming-fishing, Transport-moving, Priv-house-serv, Protective-serv, Armed-Forces.
# relationship: Wife, Own-child, Husband, Not-in-family, Other-relative, Unmarried.
# race: White, Asian-Pac-Islander, Amer-Indian-Eskimo, Other, Black.
# sex: Female, Male.
# capital-gain: continuous.
# capital-loss: continuous.
# hours-per-week: continuous.
# native-country: United-States, Cambodia, England, Puerto-Rico, Canada, Germany, Outlying-US(Guam-USVI-etc), India, Japan, Greece, South, China, Cuba, Iran, Honduras, Philippines, Italy, Poland, Jamaica, Vietnam, Mexico, Portugal, Ireland, France, Dominican-Republic, Laos, Ecuador, Taiwan, Haiti, Columbia, Hungary, Guatemala, Nicaragua, Scotland, Thailand, Yugoslavia, El-Salvador, Trinadad&Tobago, Peru, Hong, Holand-Netherlands.
# class: >50K, <=50K

# %%
df.columns=['age','workclass','fnlwgt','education','education-num','marital-status','occupation','relationship','race','sex','capital-gain',
           'capital-loss','hours-per-week','native-country','class']

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country   class
# 0          2174             0              40   United-States   <=50K
# ...

# %%
sns.heatmap(df.isnull())

# %%
# by exploring data we can see that there were '?' (missing Values) in the data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  class           32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# class             object
# dtype: object

# %%
df.head(20)
# Out:
#     age          workclass  fnlwgt      education  education-num  \
# 0    39          State-gov   77516      Bachelors             13
# 1    50   Self-emp-not-inc   83311      Bachelors             13
# 2    38            Private  215646        HS-grad              9
# 3    53            Private  234721           11th              7
# 4    28            Private  338409      Bachelors             13
# 5    37            Private  284582        Masters             14
# 6    49            Private  160187            9th              5
# 7    52   Self-emp-not-inc  209642        HS-grad              9
# 8    31            Private   45781        Masters             14
# 9    42            Private  159449      Bachelors             13
# 10   37            Private  280464   Some-college             10
# 11   30          State-gov  141297      Bachelors             13
# 12   23            Private  122272      Bachelors             13
# ...

# %%
for cols in df.columns:
    if df[cols].dtypes =='object':
        print("Column Name is {} and  no of Unique values are {}".format(cols, len(df[cols].value_counts())))
        print()
# Out:
# Column Name is workclass and  no of Unique values are 9
#
# Column Name is education and  no of Unique values are 16
#
# Column Name is marital-status and  no of Unique values are 7
#
# Column Name is occupation and  no of Unique values are 15
#
# Column Name is relationship and  no of Unique values are 6
#
# Column Name is race and  no of Unique values are 5
#
# Column Name is sex and  no of Unique values are 2
#
# Column Name is native-country and  no of Unique values are 42
#
# Column Name is class and  no of Unique values are 2

# %%
for col in df.columns:
    if df[col].dtype=="object":
        print(df[col].value_counts())
        print()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: workclass, dtype: int64
#
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64
#
#  Married-civ-spouse       14976
#  Never-married            10683
#  Divorced                  4443
#  Separated                 1025
#  Widowed                    993
#  Married-spouse-absent      418
#  Married-AF-spouse           23
# ...

# %%
# Missing values in workclass, occupation,native country

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country   class
# 0          2174             0              40   United-States   <=50K
# ...

# %%
# We will impute missing values using in the data taking support of other variables

# %%
plt.figure(figsize=(25,8))
sns.boxplot(x='occupation',y='hours-per-week',data=df)

# %%
plt.figure(figsize=(25,8))
sns.boxplot(x='occupation',y='age',data=df)

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='workclass',y='education-num',data=df)

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='workclass',y='hours-per-week',data=df)

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='workclass',y='age',data=df)

# %%
# mean of '?' is similar to mean of 'Private'

# %%
df.replace(' ?', np.nan, inplace=True)

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education-num        0
# marital-status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital-gain         0
# capital-loss         0
# hours-per-week       0
# native-country     583
# class                0
# dtype: int64

# %%
# filling missing data with modes of respective columns
df['workclass']=df['workclass'].fillna('Private')
df['occupation']=df['occupation'].fillna('Prof-specialty')
df['native-country']=df['native-country'].fillna('United-States')

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education-num     0
# marital-status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital-gain      0
# capital-loss      0
# hours-per-week    0
# native-country    0
# class             0
# dtype: int64

# %%
df.dtypes
# Out:
# age                int64
# workclass         object
# fnlwgt             int64
# education         object
# education-num      int64
# marital-status    object
# occupation        object
# relationship      object
# race              object
# sex               object
# capital-gain       int64
# capital-loss       int64
# hours-per-week     int64
# native-country    object
# class             object
# dtype: object

# %% [markdown]
# ##### creating categorical and numerical sets

# %%
categorical=df.select_dtypes(include=['object']).keys()
categorical
# Out:
# Index(['workclass', 'education', 'marital-status', 'occupation',
#        'relationship', 'race', 'sex', 'native-country', 'class'],
#       dtype='object')

# %%
numerical=df.select_dtypes(include=['int64']).keys()
numerical
# Out:
# Index(['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss',
#        'hours-per-week'],
#       dtype='object')

# %% [markdown]
# ### Plotting categorical data

# %%
plt.figure(figsize=(15,5))
sns.countplot('workclass', hue='class',data=df)

# %%
 # income in self employment is >50k, rest in all cases it is <=50k

# %%
plt.figure(figsize=(19,10))
sns.countplot('education', hue='class',data=df)

# %%
# most of some college, HS grad and below that classes will get <=50k. 
# Having masters, Doctorate, Prof School degree will get >50K

# %%
plt.figure(figsize=(19,5))
sns.countplot('marital-status', hue='class',data=df)

# %%
# most of never married income is <=50K

# %%
plt.figure(figsize=(25,10))
sns.countplot('occupation', hue='class',data=df)

# %%
# Income in Executive management is very competitive and has almost equal split than the rest

# %%
plt.figure(figsize=(25,10))
sns.countplot('relationship', hue='class',data=df)

# %%
plt.figure(figsize=(25,10))
sns.countplot('race', hue='class',data=df)

# %%
plt.figure(figsize=(15,5))
sns.countplot('sex', hue='class',data=df)

# %%
# male are more in number

# %%
plt.figure(figsize=(25,10))
sns.countplot('native-country', hue='class',data=df)

# %%
def conv_class(x):
    if x==' >50K':
        return 1
    if x==' <=50K':
        return 0

# %%
df['class']=df['class'].apply(conv_class)

# %%
df['class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
sns.factorplot(x="native-country",y="class",data=df,kind="bar", size = 25, 
palette = "muted")

# %%
sns.factorplot(x="occupation",y="class",data=df,kind="bar", size = 25, 
palette = "muted")

# %% [markdown]
# ### Plotting Numerical data

# %%
numerical
# Out:
# Index(['age', 'fnlwgt', 'education-num', 'capital-gain', 'capital-loss',
#        'hours-per-week'],
#       dtype='object')

# %%
sns.boxplot(x='class', y='age',data=df)

# %%
sns.boxplot(x='class', y='fnlwgt',data=df)

# %%
sns.boxplot(x='class', y='education-num',data=df)

# %%
sns.boxplot(x='class', y='capital-gain',data=df)

# %%
sns.boxplot(x='class', y='capital-loss',data=df)

# %%
sns.boxplot(x='class', y='hours-per-week',data=df)

# %%
def conv_sex(x):
    if x==' Male':
        return 1
    if x==' Female':
        return 0

# %%
df['sex']=df['sex'].apply(conv_sex)

# %%
df['sex'].value_counts()
# Out:
# 1    21790
# 0    10771
# Name: sex, dtype: int64

# %%
sns.boxplot(x='class', y='sex',data=df)

# %%
sns.factorplot(x="age",y="class",data=df,kind="bar", size = 25, 
palette = "muted")

# %%
# As the Age increases income increases

# %%
sns.factorplot(x="education-num",y="class",data=df,kind="bar", size = 25, 
palette = "muted")

# %%
# as the education increases income increases

# %%
plt.scatter(df["native-country"],df["class"],c="g") 
plt.ylabel("income")
plt.xlabel("native-country")
# Out:
# Text(0.5, 0, 'native-country')

# %%
sns.stripplot(x='race',y='class',data=df)

# %%
df['education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5355
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: education, dtype: int64

# %%
df['education-num'].value_counts()
# Out:
# 9     10501
# 10     7291
# 13     5355
# 14     1723
# 11     1382
# 7      1175
# 12     1067
# 6       933
# 4       646
# 15      576
# 5       514
# 8       433
# 16      413
# 3       333
# 2       168
# 1        51
# Name: education-num, dtype: int64

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race  sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White    1
# 1   Married-civ-spouse     Exec-managerial         Husband   White    1
# 2             Divorced   Handlers-cleaners   Not-in-family   White    1
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black    1
# 4   Married-civ-spouse      Prof-specialty            Wife   Black    0
#
#    capital-gain  capital-loss  hours-per-week  native-country  class
# 0          2174             0              40   United-States      0
# ...

# %%
# we will create dummy variables for workclass,marital-status, occupation
# race, native country,relationship doesnt effect the model. so let us remove them
# also removing education as education number represent the same

# %%
dummy= pd.get_dummies(df,columns=["workclass","marital-status","occupation"])
dummy
# Out:
#        age  fnlwgt    education  education-num    relationship    race  sex  \
# 0       39   77516    Bachelors             13   Not-in-family   White    1
# 1       50   83311    Bachelors             13         Husband   White    1
# 2       38  215646      HS-grad              9   Not-in-family   White    1
# 3       53  234721         11th              7         Husband   Black    1
# 4       28  338409    Bachelors             13            Wife   Black    0
# ...    ...     ...          ...            ...             ...     ...  ...
# 32556   27  257302   Assoc-acdm             12            Wife   White    0
# 32557   40  154374      HS-grad              9         Husband   White    1
# 32558   58  151910      HS-grad              9       Unmarried   White    0
# 32559   22  201490      HS-grad              9       Own-child   White    1
# 32560   52  287927      HS-grad              9            Wife   White    0
#
# ...

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race  sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White    1
# 1   Married-civ-spouse     Exec-managerial         Husband   White    1
# 2             Divorced   Handlers-cleaners   Not-in-family   White    1
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black    1
# 4   Married-civ-spouse      Prof-specialty            Wife   Black    0
#
#    capital-gain  capital-loss  hours-per-week  native-country  class
# 0          2174             0              40   United-States      0
# ...

# %%
dummy.head()
# Out:
#    age  fnlwgt   education  education-num    relationship    race  sex  \
# 0   39   77516   Bachelors             13   Not-in-family   White    1
# 1   50   83311   Bachelors             13         Husband   White    1
# 2   38  215646     HS-grad              9   Not-in-family   White    1
# 3   53  234721        11th              7         Husband   Black    1
# 4   28  338409   Bachelors             13            Wife   Black    0
#
#    capital-gain  capital-loss  hours-per-week  ...  \
# 0          2174             0              40  ...
# 1             0             0              13  ...
# 2             0             0              40  ...
# 3             0             0              40  ...
# 4             0             0              40  ...
#
#   occupation_ Handlers-cleaners  occupation_ Machine-op-inspct  \
# 0                             0                              0
# 1                             0                              0
# ...

# %%
data=dummy.drop(columns=["relationship","race","native-country"])

# %%
data.head()
# Out:
#    age  fnlwgt   education  education-num  sex  capital-gain  capital-loss  \
# 0   39   77516   Bachelors             13    1          2174             0
# 1   50   83311   Bachelors             13    1             0             0
# 2   38  215646     HS-grad              9    1             0             0
# 3   53  234721        11th              7    1             0             0
# 4   28  338409   Bachelors             13    0             0             0
#
#    hours-per-week  class  workclass_ Federal-gov  ...  \
# 0              40      0                       0  ...
# 1              13      0                       0  ...
# 2              40      0                       0  ...
# 3              40      0                       0  ...
# 4              40      0                       0  ...
#
#    occupation_ Handlers-cleaners  occupation_ Machine-op-inspct  \
# 0                              0                              0
# ...

# %%
data.drop('education',axis=1,inplace=True)

# %%
data.head()
# Out:
#    age  fnlwgt  education-num  sex  capital-gain  capital-loss  \
# 0   39   77516             13    1          2174             0
# 1   50   83311             13    1             0             0
# 2   38  215646              9    1             0             0
# 3   53  234721              7    1             0             0
# 4   28  338409             13    0             0             0
#
#    hours-per-week  class  workclass_ Federal-gov  workclass_ Local-gov  ...  \
# 0              40      0                       0                     0  ...
# 1              13      0                       0                     0  ...
# 2              40      0                       0                     0  ...
# 3              40      0                       0                     0  ...
# 4              40      0                       0                     0  ...
#
#    occupation_ Handlers-cleaners  occupation_ Machine-op-inspct  \
# ...

# %%
data.dtypes
# Out:
# age                                      int64
# fnlwgt                                   int64
# education-num                            int64
# sex                                      int64
# capital-gain                             int64
# capital-loss                             int64
# hours-per-week                           int64
# class                                    int64
# workclass_ Federal-gov                   uint8
# workclass_ Local-gov                     uint8
# workclass_ Never-worked                  uint8
# workclass_ Private                       uint8
# workclass_ Self-emp-inc                  uint8
# workclass_ Self-emp-not-inc              uint8
# workclass_ State-gov                     uint8
# workclass_ Without-pay                   uint8
# workclass_Private                        uint8
# marital-status_ Divorced                 uint8
# marital-status_ Married-AF-spouse        uint8
# marital-status_ Married-civ-spouse       uint8
# ...

# %%
data_corr=data.corr()

# %%
data.head()
# Out:
#    age  fnlwgt  education-num  sex  capital-gain  capital-loss  \
# 0   39   77516             13    1          2174             0
# 1   50   83311             13    1             0             0
# 2   38  215646              9    1             0             0
# 3   53  234721              7    1             0             0
# 4   28  338409             13    0             0             0
#
#    hours-per-week  class  workclass_ Federal-gov  workclass_ Local-gov  ...  \
# 0              40      0                       0                     0  ...
# 1              13      0                       0                     0  ...
# 2              40      0                       0                     0  ...
# 3              40      0                       0                     0  ...
# 4              40      0                       0                     0  ...
#
#    occupation_ Handlers-cleaners  occupation_ Machine-op-inspct  \
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(data_corr)

# %%
x=data.drop('class',axis=1)
y=data['class']

# %%
x.shape
# Out:
# (32561, 38)

# %%
y.shape
# Out:
# (32561,)

# %%
from sklearn.preprocessing import StandardScaler
ss= StandardScaler()
x=ss.fit_transform(x)

# %%
x
# Out:
# array([[ 0.03067056, -1.06361075,  1.13473876, ..., -0.17127887,
#         -0.22710355, -0.24494366],
#        [ 0.83710898, -1.008707  ,  1.13473876, ..., -0.17127887,
#         -0.22710355, -0.24494366],
#        [-0.04264203,  0.2450785 , -0.42005962, ..., -0.17127887,
#         -0.22710355, -0.24494366],
#        ...,
#        [ 1.42360965, -0.35877741, -0.42005962, ..., -0.17127887,
#         -0.22710355, -0.24494366],
#        [-1.21564337,  0.11095988, -0.42005962, ..., -0.17127887,
#         -0.22710355, -0.24494366],
#        [ 0.98373415,  0.92989258, -0.42005962, ..., -0.17127887,
#         -0.22710355, -0.24494366]])

# %%
y
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 32556    0
# 32557    1
# 32558    0
# 32559    0
# 32560    1
# Name: class, Length: 32561, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score,accuracy_score,f1_score
def max_auc_roc_score(algo,x,y):
    max_auc_roc_score=0
    for r_state in range(42,80):
        x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.20)
        algo.fit(x_train,y_train)
        y_pred = algo.predict(x_test)
        aucroc_scr=roc_auc_score(y_test,y_pred)
        print("auc roc score corresponding to ",r_state," is ",aucroc_scr)
        if aucroc_scr>max_auc_roc_score:
            max_auc_roc_score=aucroc_scr
            final_r_state=r_state
    print("max auc roc score corresponding to ",final_r_state," is ",max_auc_roc_score)
    print("Accuracy is=",accuracy_score(y_test,y_pred))
    print("F1 Score= ",f1_score(y_test,y_pred))
    return final_r_state

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lg_algo = LogisticRegression()
max_auc_roc_score(lg_algo,x,y)
# Out:
# auc roc score corresponding to  42  is  0.7735965075203357
# auc roc score corresponding to  43  is  0.7648572338530935
# auc roc score corresponding to  44  is  0.7615024927225883
# auc roc score corresponding to  45  is  0.7611005932516378
# auc roc score corresponding to  46  is  0.7659865263868175
# auc roc score corresponding to  47  is  0.7609967482893101
# auc roc score corresponding to  48  is  0.7660429283635025
# auc roc score corresponding to  49  is  0.7641697312197444
# auc roc score corresponding to  50  is  0.7821201319512845
# auc roc score corresponding to  51  is  0.770355155482815
# auc roc score corresponding to  52  is  0.7494776200839803
# auc roc score corresponding to  53  is  0.750290818777218
# auc roc score corresponding to  54  is  0.7632562418452195
# auc roc score corresponding to  55  is  0.7593304084668966
# auc roc score corresponding to  56  is  0.7664119768612848
# auc roc score corresponding to  57  is  0.7595142063359823
# ...

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(lg_algo,x,y,cv=5,scoring="roc_auc").mean()
# Out:
# 0.9039292491159635

# %% [markdown]
# #### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
dt_algo=DecisionTreeClassifier()
max_auc_roc_score(dt_algo,x,y)
# Out:
# auc roc score corresponding to  42  is  0.7569152261716496
# auc roc score corresponding to  43  is  0.7510057652434466
# auc roc score corresponding to  44  is  0.7455038980158597
# auc roc score corresponding to  45  is  0.7482265668930318
# auc roc score corresponding to  46  is  0.7536854119858133
# auc roc score corresponding to  47  is  0.7546319007243771
# auc roc score corresponding to  48  is  0.7619316090607956
# auc roc score corresponding to  49  is  0.7538984633051441
# auc roc score corresponding to  50  is  0.756990369432328
# auc roc score corresponding to  51  is  0.7505294599018003
# auc roc score corresponding to  52  is  0.7557058334409217
# auc roc score corresponding to  53  is  0.7376473159304948
# auc roc score corresponding to  54  is  0.7501480584296142
# auc roc score corresponding to  55  is  0.7518845254123708
# auc roc score corresponding to  56  is  0.7501348587398612
# auc roc score corresponding to  57  is  0.7396997078423073
# ...

# %%
cross_val_score(dt_algo,x,y,cv=5,scoring="roc_auc").mean()
# Out:
# 0.7454271527996535

# %% [raw]
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.model_selection import GridSearchCV
# parameters={"n_estimators":[10,100,500],'criterion' : ("gini", "entropy")}
# rf=RandomForestClassifier()
# gsv = GridSearchCV(rf, parameters, cv=5,scoring="roc_auc")
# gsv.fit(x,y)
# gsv.best_params_

# %% [raw]
# rf_algo =RandomForestClassifier(n_estimators=500,criterion='entropy')
# max_auc_roc_score(rf_algo,x,y)

# %% [raw]
# cross_val_score(rf_algo,x,y,cv=5,scoring="roc_auc").mean()

# %% [raw]
# from sklearn.model_selection import GridSearchCV
# from sklearn.neighbors import KNeighborsClassifier
# knn=KNeighborsClassifier()
# neighbors={"n_neighbors":range(1,30)}
# gsv = GridSearchCV(knn, neighbors, cv=5,scoring="roc_auc")
# gsv.fit(x,y)
# gsv.best_params_

# %% [raw]
# from sklearn.neighbors import KNeighborsClassifier
# knn_algo=KNeighborsClassifier(n_neighbors=10)
# max_auc_roc_score(knn_algo,x,y)

# %% [raw]
# from sklearn.svm import SVC
# svc=SVC()
# parameters={"kernel":["linear", "poly", "rbf"],"C":[0.001,0.01,0.1,1,10]}
# gsv = GridSearchCV(svc, parameters, cv=5,scoring="roc_auc")
# gsv.fit(x,y)
# gsv.best_params_

# %% [raw]
# svc_algo=SVC(kernel='linear',C=0.01)
# max_auc_roc_score(svc_algo,x,y)

# %%
plt.figure(figsize=(30,35))
sns.heatmap(data_corr,cmap='YlGnBu',annot=True)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race  sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White    1
# 1   Married-civ-spouse     Exec-managerial         Husband   White    1
# 2             Divorced   Handlers-cleaners   Not-in-family   White    1
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black    1
# 4   Married-civ-spouse      Prof-specialty            Wife   Black    0
#
#    capital-gain  capital-loss  hours-per-week  native-country  class
# 0          2174             0              40   United-States      0
# ...

# %% [markdown]
# ### Bagging

# %%
from sklearn.ensemble import BaggingClassifier
bg_algo = BaggingClassifier(max_samples=0.5,max_features=0.5)

# %%
max_auc_roc_score(bg_algo,x,y)
# Out:
# auc roc score corresponding to  42  is  0.7359776977548087
# auc roc score corresponding to  43  is  0.746914782292188
# auc roc score corresponding to  44  is  0.7416878575969484
# auc roc score corresponding to  45  is  0.758383880058693
# auc roc score corresponding to  46  is  0.7530247454357476
# auc roc score corresponding to  47  is  0.7438766889167527
# auc roc score corresponding to  48  is  0.73686636330177
# auc roc score corresponding to  49  is  0.7366709216525594
# auc roc score corresponding to  50  is  0.7384845535700327
# auc roc score corresponding to  51  is  0.7436603927986908
# auc roc score corresponding to  52  is  0.7319005637630105
# auc roc score corresponding to  53  is  0.7364498938027715
# auc roc score corresponding to  54  is  0.7315532306040887
# auc roc score corresponding to  55  is  0.7400044649169726
# auc roc score corresponding to  56  is  0.7193291021647659
# auc roc score corresponding to  57  is  0.7270935510044408
# ...

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb_algo= GradientBoostingClassifier(n_estimators=200,learning_rate=.02)
max_auc_roc_score(gb_algo,x,y)
# Out:
# auc roc score corresponding to  42  is  0.7592493677776144
# auc roc score corresponding to  43  is  0.7513223661547062
# auc roc score corresponding to  44  is  0.7507210492856425
# auc roc score corresponding to  45  is  0.7493403693931397
# auc roc score corresponding to  46  is  0.7544140597914224
# auc roc score corresponding to  47  is  0.7426665550162559
# auc roc score corresponding to  48  is  0.7502894234951651
# auc roc score corresponding to  49  is  0.7511992903889668
# auc roc score corresponding to  50  is  0.7668984412863686
# auc roc score corresponding to  51  is  0.7610818330605564
# auc roc score corresponding to  52  is  0.7404221383033007
# auc roc score corresponding to  53  is  0.7414833540871325
# auc roc score corresponding to  54  is  0.7556246137885582
# auc roc score corresponding to  55  is  0.7491137408780438
# auc roc score corresponding to  56  is  0.7456687119916938
# auc roc score corresponding to  57  is  0.7508419067765474
# ...

# %% [markdown]
# #### Gaussian Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb_algo=GaussianNB()
max_auc_roc_score(gnb_algo,x,y)
# Out:
# auc roc score corresponding to  42  is  0.6131460395714412
# auc roc score corresponding to  43  is  0.5512968872885157
# auc roc score corresponding to  44  is  0.6383042794526048
# auc roc score corresponding to  45  is  0.6314627994955864
# auc roc score corresponding to  46  is  0.6288758371202752
# auc roc score corresponding to  47  is  0.6101643764139626
# auc roc score corresponding to  48  is  0.6376969920032121
# auc roc score corresponding to  49  is  0.6324324154541423
# auc roc score corresponding to  50  is  0.6312606506886794
# auc roc score corresponding to  51  is  0.6330286415711948
# auc roc score corresponding to  52  is  0.6345394372821336
# auc roc score corresponding to  53  is  0.6316329635590603
# auc roc score corresponding to  54  is  0.6179485245052123
# auc roc score corresponding to  55  is  0.6378863959128719
# auc roc score corresponding to  56  is  0.6270906032147514
# auc roc score corresponding to  57  is  0.6113451465911314
# ...

# %% [markdown]
# #### Bernouli Naive Bayes

# %%
from sklearn.naive_bayes import BernoulliNB
bn_algo=BernoulliNB()
max_auc_roc_score(bn_algo,x,y)
# Out:
# auc roc score corresponding to  42  is  0.7822563506245973
# auc roc score corresponding to  43  is  0.7812925324823045
# auc roc score corresponding to  44  is  0.7810645096530264
# auc roc score corresponding to  45  is  0.7770124140317489
# auc roc score corresponding to  46  is  0.7779620940141307
# auc roc score corresponding to  47  is  0.7796753114878724
# auc roc score corresponding to  48  is  0.778768360825777
# auc roc score corresponding to  49  is  0.778934930125677
# auc roc score corresponding to  50  is  0.7801586464049528
# auc roc score corresponding to  51  is  0.786150572831424
# auc roc score corresponding to  52  is  0.7678952104735732
# auc roc score corresponding to  53  is  0.766383360233596
# auc roc score corresponding to  54  is  0.7780232708780379
# auc roc score corresponding to  55  is  0.772978568398532
# auc roc score corresponding to  56  is  0.7769375941669204
# auc roc score corresponding to  57  is  0.7701423738355866
# ...

# %%
#Bernouli Naive Bayes gave us high Auc ROC Score

# %%
from sklearn.metrics import confusion_matrix,classification_report,f1_score
bnb= BernoulliNB()
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state =76 ,test_size=0.20)
bnb.fit(x_train,y_train)
pred=bnb.predict(x_test)

print("AUC_ROC Score =",roc_auc_score(y_test,pred))
print("Accuracy Score= ",accuracy_score(y_test,pred))
print("Confusion Matrix =", confusion_matrix(y_test,pred))
print("Classification Report= ", classification_report(y_test,pred))
# Out:
# AUC_ROC Score = 0.790638430369241
# Accuracy Score=  0.8243512974051896
# Confusion Matrix = [[4264  730]
#  [ 414 1105]]
# Classification Report=                precision    recall  f1-score   support
#
#            0       0.91      0.85      0.88      4994
#            1       0.60      0.73      0.66      1519
#
#     accuracy                           0.82      6513
#    macro avg       0.76      0.79      0.77      6513
# weighted avg       0.84      0.82      0.83      6513

# %%
import joblib

# %%
joblib.dump(bnb,'Census_data_bnb.pkl')
# Out:
# ['Census_data_bnb.pkl']
